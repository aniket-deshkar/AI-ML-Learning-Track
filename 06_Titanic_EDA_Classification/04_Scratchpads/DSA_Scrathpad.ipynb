# %%
from fontTools.misc.cython import returns

#Two Sum

nums = [2,8,9,11,7]
k = 9

def two_sum(nums, k):
    for i in range(len(nums)):
        for j in range(i+1,len(nums)):
            if nums[i] + nums[j] == k:
                print(nums[i],nums[j])
    return []
print(two_sum(nums,k))

#Two sum using set/HashMap

def two_sum(nums, k):
    seen_set = {}

    for i, num in enumerate(nums):
        complement = k - num
        if complement in seen_set:
            return [seen_set[complement], i]
        seen_set[num] = i
    return []
print(two_sum(nums,k))
# Out:
# 2 7
# []
# [0, 4]

# %%
#Maximum Subarray or Kadane's algorithm
array = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
# Output: 6  (subarray [4, -1, 2, 1])
def maximum_subarray(input_list):
    current_sum = input_list[0]
    max_sum = input_list[0]

    for num in input_list[1:]:
        current_sum = max(num, current_sum + num)
        max_sum = max(max_sum, current_sum)

    return max_sum

print(maximum_subarray(array))
# Out:
# 6
