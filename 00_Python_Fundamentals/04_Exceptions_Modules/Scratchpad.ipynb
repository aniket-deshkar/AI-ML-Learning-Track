# %%
tuple_1 = (1,2,3,4,5)
try:
    tuple_1.append(6,7,8)
    print(tuple_1)
except AttributeError:
    print("AttributeError. Tuple cannot be appended")
# Out:
# AttributeError. Tuple cannot be appended

# %%
text = "Konverge.AI"
try:
    var_a = open("any_file.txt","x")
except FileExistsError as error:
    print(error)
# Out:
# [Errno 17] File exists: 'any_file.txt'

# %%
try:
    x=2/0
except ZeroDivisionError as error:
    print("Error: ",error)
# Out:
# Error:  division by zero

# %%
try:
    x = 2/4
except ZeroDivisionError as error:
    print("Error: ",error)
else:
    print("Else Block")
finally:
    print("Printed finally Block")
# Out:
# Else Block
# Printed finally Block

# %%
try:
    x = "String Value"
    if type(x) is not int:
        raise TypeError("Only String are allowed")
except TypeError as error:
            print(error)
# Out:
# Only String are allowed

# %%
from Exceptions import InsertIntError
x = 10
y = "20"

try:
    if type(y) is not int:
        raise InsertIntError("Enter similar data types")
except InsertIntError as error:
    print("InsertInt",error)
# Out:
# InsertInt Enter similar data types

# %%
import traceback

try:
    x = "Konverge.AI"
    print(x)
except:
    print(traceback.print_exc())
# Out:
# 0
