# %%
data2 = "Hello World! \n"
file2 = open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data.txt", 'w')
file2.write(data2)
file2.close()

# %%
file3 = open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data.txt")
data3 = file3.readline()
print(data3)
file3.close()
# Out:
# Hello World!

# %%
data4 = "new Hello World Order! \n"
file4 = open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data.txt", 'a')
file4.write(data4)
file4.close()

# %%
file5 = open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data.txt")
data5 = file5.read()
print(data5)
file5.close()
# Out:
# Hello World!
# new Hello World Order!

# %%
with open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data.txt","r") as file:
    data6 = file.read(10)
    print(data6)
    print("log_file tell: ",file.tell())
    print("",file.seek(0))
    # for line in log_file:
    #     print(line, end='')
    # file_contents = log_file.read(1)
    # print("File contents",file_contents)
# Out:
# Hello Worl
# file tell:  10
#  0

# %%
with open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data.txt","w") as file:
    file.write('Overwriting data 1 \n')
    file.write('Overwriting data 2 \n')

# %%
with open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data.txt","r") as read_file:
    with open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data_copy.txt","w") as write_file:
        for line in read_file:
            write_file.write(line)

# %%
with open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/write_data_copy.txt","r") as read_file:
    data7 = read_file.read()
    print(data7)
# Out:
# Overwriting data 1
# Overwriting data 2

# %%
with open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/pexels-eberhardgross-691668.jpg","rb") as read_file:
    with open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/pexels-eberhardgross.jpg", "wb") as write_file:
        chunk_size = 1024
        read_file_chunk = read_file.read(chunk_size)
        while len(read_file_chunk) > 0:
            write_file.write(read_file_chunk)
            read_file_chunk = read_file.read(chunk_size)

# %%
with open("/home/aniket-deshkar/PycharmProjects/Path2AI/PythonTrack/File Handling + Functions/pexels-eberhardgross.jpg","rb") as read_file:
    data7 = read_file.read()
    print(data7)
# Out:
# b''
